# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r"D:\My Work\Top_Dataset\HousePrice.csv")

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# ### 1) Find those owners who has flat rates under 50 lac and Rera Approved

# %%
data=dataset.loc[(dataset["POSTED_BY"]=="Owner")&(dataset["TARGET(PRICE_IN_LACS)"]<50)&(dataset["RERA"]==0)]
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 2         Owner                   0     0        2       BHK   933.159722
# 5         Owner                   0     0        3       BHK  1250.000000
# 10        Owner                   0     0        3       BHK  1350.308642
# 12        Owner                   0     0        2       BHK   927.177902
# 14        Owner                   0     0        1       BHK   649.983750
# ...         ...                 ...   ...      ...       ...          ...
# 29431     Owner                   0     0        2       BHK   712.105799
# 29441     Owner                   0     0        3       BHK  1500.375094
# 29445     Owner                   0     0        2       BHK  1062.134891
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
data["TARGET(PRICE_IN_LACS)"].unique()
# Out:
# array([43.  , 42.  , 35.  , 48.  , 20.  , 22.  , 45.  , 27.5 , 46.  ,
#        39.  , 38.  , 32.5 , 30.  , 33.  , 29.  , 34.  , 18.  , 49.  ,
#        21.2 , 14.5 , 25.  , 37.  , 40.  , 31.  , 16.  , 26.  , 24.  ,
#        23.  , 14.  , 27.  , 22.4 ,  8.5 , 12.  , 31.2 , 12.5 , 13.5 ,
#        17.  , 47.  , 43.5 ,  9.  , 28.  , 13.  , 32.  , 15.3 , 18.5 ,
#        24.2 , 10.2 , 36.  , 30.7 , 42.5 , 21.  , 38.2 , 11.  , 15.  ,
#        44.  , 28.1 , 14.7 , 16.2 , 30.5 , 11.5 , 23.5 , 15.4 , 14.9 ,
#        19.5 ,  6.5 , 19.  , 17.5 , 18.9 , 38.5 , 12.1 , 46.4 , 20.5 ,
#        33.8 , 26.7 , 48.4 , 16.5 , 10.  , 32.7 , 25.9 , 28.5 , 16.7 ,
#        21.5 , 37.5 , 14.2 , 15.7 , 21.9 ,  7.5 , 23.8 , 27.3 , 41.  ,
#        11.2 , 49.5 , 15.6 ,  8.  , 47.8 , 22.5 , 33.9 , 15.9 , 22.7 ,
#        13.9 , 36.5 , 31.5 , 42.2 , 14.8 , 29.7 , 27.2 , 19.4 , 22.9 ,
#        41.5 , 18.8 , 24.5 , 40.5 , 26.9 , 46.5 , 34.7 , 15.2 , 15.5 ,
# ...

# %% [markdown]
# # 2) How to setup 2 precisions for Squere Feet

# %%
dataset["SQUARE_FT"]=dataset["SQUARE_FT"].round(2)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  SQUARE_FT  \
# 0         Owner                   0     0        2       BHK    1300.24
# 1        Dealer                   0     0        2       BHK    1275.00
# 2         Owner                   0     0        2       BHK     933.16
# 3         Owner                   0     1        2       BHK     929.92
# 4        Dealer                   1     0        2       BHK     999.01
# ...         ...                 ...   ...      ...       ...        ...
# 29446     Owner                   0     0        3       BHK    2500.00
# 29447     Owner                   0     0        2       BHK     769.23
# 29448    Dealer                   0     0        2       BHK    1022.64
# 29449     Owner                   0     0        2       BHK     927.08
# 29450    Dealer                   0     1        2       BHK     896.77
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# ### 3) Slice the cities and find the benglores rera approved flates

# %%
dataset=pd.read_csv(r"D:\My Work\Top_Dataset\HousePrice.csv")

# %%
dataset.shape
# Out:
# (29451, 12)

# %%
dataset["ADDRESS"]=dataset["ADDRESS"].str.split(",").str.get(1)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE               ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %%
dataset["ADDRESS"].unique()
# Out:
# array(['Bangalore', 'Mysore', 'Ghaziabad', 'Kolkata', 'Kochi', 'Jaipur',
#        'Mohali', 'Chennai', 'Siliguri', 'Noida', 'Raigad', 'Bhubaneswar',
#        'Wardha', 'Pune', 'Mumbai', 'Nagpur', 'Deoghar', 'Bhiwadi',
#        'Faridabad', 'Lalitpur', 'Maharashtra', 'Vadodara',
#        'Visakhapatnam', 'Vapi', 'Mangalore', 'Aurangabad', 'Ottapalam',
#        'Vijayawada', 'Belgaum', 'Bhopal', 'Lucknow', 'Kanpur',
#        'Gandhinagar', 'Pondicherry', 'Agra', 'Ranchi', 'Gurgaon', 'Udupi',
#        'Indore', 'Jodhpur', 'Coimbatore', 'Valsad', 'Palghar', 'Surat',
#        'Varanasi', 'Guwahati', 'Amravati', 'Anand', 'Tirupati',
#        'Secunderabad', 'Raipur', 'Vizianagaram', 'Thrissur', 'Satna',
#        'Madurai', 'Chandigarh', 'Shimla', 'Gwalior', 'Rajkot', 'Sonipat',
#        'Allahabad', 'Berhampur', 'C V Raman Nagar', ' Mahalaxmi 2',
#        'Roorkee', 'Dharuhera', 'Latur', 'Durgapur', 'Panchkula',
#        'Solapur', 'Durg', 'Goa', 'Jamshedpur', 'Hazaribagh', 'Jabalpur',
# ...

# %%
dataset["ADDRESS"].nunique()
# Out:
# 433

# %%
dataset["ADDRESS"].value_counts()
# Out:
# Bangalore            4319
# Lalitpur             2987
# Mumbai               2020
# Pune                 1984
# Noida                1765
#                      ...
# Chhindwara              1
# Karaikudi               1
# Gondia                  1
# Opp.Mafatlal Mill       1
#  Waghapur               1
# Name: ADDRESS, Length: 433, dtype: int64

# %%
data_Beng=dataset.loc[dataset["ADDRESS"]=="Bangalore"]

# %%
data_Beng
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 2         Owner                   0     0        2       BHK   933.159722
# 8        Dealer                   0     1        2       BHK  1040.000000
# 11       Dealer                   0     0        2       BHK  1333.010179
# 12        Owner                   0     0        2       BHK   927.177902
# ...         ...                 ...   ...      ...       ...          ...
# 29408    Dealer                   0     0        2       BHK  1105.845182
# 29415     Owner                   0     0        4       BHK  3650.240584
# 29421    Dealer                   0     0        2       BHK  1409.064497
# 29433     Owner                   0     0        2       BHK  1195.028681
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE    ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %%
beng_rera_data=dataset.loc[(dataset["ADDRESS"]=="Bangalore")&(dataset["RERA"]==0)]

# %%
beng_rera_data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 2         Owner                   0     0        2       BHK   933.159722
# 11       Dealer                   0     0        2       BHK  1333.010179
# 12        Owner                   0     0        2       BHK   927.177902
# 39        Owner                   0     0        3       BHK  1300.052002
# ...         ...                 ...   ...      ...       ...          ...
# 29394    Dealer                   0     0        2       BHK  1187.024284
# 29408    Dealer                   0     0        2       BHK  1105.845182
# 29415     Owner                   0     0        4       BHK  3650.240584
# 29421    Dealer                   0     0        2       BHK  1409.064497
# 29433     Owner                   0     0        2       BHK  1195.028681
#
#        READY_TO_MOVE  RESALE    ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# ## 4) Rename the Address cols with City Name ?

# %%
dataset.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE    ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# 2              1       1  Bangalore  12.778033  77.632191
# 3              1       1  Ghaziabad  28.642300  77.344500
# 4              0       1    Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# 2                   43.0
# 3                   62.5
# 4                   60.5

# %%
dataset=dataset.rename(columns={"ADDRESS":"City_Name"}) # Rename your cols name

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE             City_Name  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# ### 5) Increses the Target price of all the flats with 10 lac and reduce the Banglores flate rates with 5 Lac

# %%
col=[]
for x in dataset["TARGET(PRICE_IN_LACS)"]:
    x1=x+10
    col.append(x1)

# %%
col
# Out:
# [65.0,
#  61.0,
#  53.0,
#  72.5,
#  70.5,
#  52.0,
#  76.5,
#  62.0,
#  51.6,
#  46.0,
#  45.0,
#  120.0,
#  58.0,
#  72.0,
#  30.0,
#  81.1,
#  95.0,
#  190.0,
#  32.0,
#  130.0,
#  55.0,
#  52.0,
#  65.0,
#  310.0,
#  60.0,
#  37.5,
#  56.0,
#  32.9,
#  49.0,
#  22.5,
#  62.0,
#  43.0,
#  65.0,
#  92.0,
#  250.0,
#  65.0,
#  75.0,
#  75.0,
#  45.0,
#  85.0,
#  9120.0,
#  75.0,
#  40.0,
#  260.0,
#  230.0,
#  48.0,
#  70.0,
#  56.0,
#  36.3,
#  61.6,
#  65.0,
#  81.9,
#  140.0,
#  42.5,
#  49.9,
#  69.9,
#  75.0,
#  120.0,
#  78.5,
#  109.0,
#  260.0,
#  37.5,
#  80.0,
#  60.0,
#  80.0,
#  32.1,
#  290.0,
#  84.0,
#  95.0,
#  59.2,
#  55.0,
#  70.0,
#  40.0,
#  43.0,
#  39.0,
#  220.0,
#  98.6,
#  790.0,
#  40.0,
#  150.0,
#  250.0,
#  170.0,
#  110.0,
#  70.0,
#  91.5,
#  44.0,
#  41.8,
#  40.0,
#  34.9,
#  58.0,
#  63.7,
#  52.0,
#  160.0,
#  450.0,
#  150.0,
#  68.0,
#  110.0,
#  28.0,
#  70.4,
#  40.0,
#  60.0,
#  150.0,
#  90.0,
#  59.0,
#  34.5,
#  28.0,
#  105.0,
#  32.0,
# ...

# %%
dataset["Updated_Price"]=col

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE             City_Name  LONGITUDE   LATITUDE  \
# ...

# %%
dataset.insert(1,"Flat_Rates",col)

# %%
dataset
# Out:
#       POSTED_BY  Flat_Rates  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0         Owner        65.0                   0     0        2       BHK
# 1        Dealer        61.0                   0     0        2       BHK
# 2         Owner        53.0                   0     0        2       BHK
# 3         Owner        72.5                   0     1        2       BHK
# 4        Dealer        70.5                   1     0        2       BHK
# ...         ...         ...                 ...   ...      ...       ...
# 29446     Owner        55.0                   0     0        3       BHK
# 29447     Owner        26.0                   0     0        2       BHK
# 29448    Dealer        37.1                   0     0        2       BHK
# 29449     Owner        77.0                   0     0        2       BHK
# 29450    Dealer        37.8                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE             City_Name  LONGITUDE  \
# ...

# %%
del dataset["Updated_Price"]

# %%
dataset
# Out:
#       POSTED_BY  Flat_Rates  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0         Owner        65.0                   0     0        2       BHK
# 1        Dealer        61.0                   0     0        2       BHK
# 2         Owner        53.0                   0     0        2       BHK
# 3         Owner        72.5                   0     1        2       BHK
# 4        Dealer        70.5                   1     0        2       BHK
# ...         ...         ...                 ...   ...      ...       ...
# 29446     Owner        55.0                   0     0        3       BHK
# 29447     Owner        26.0                   0     0        2       BHK
# 29448    Dealer        37.1                   0     0        2       BHK
# 29449     Owner        77.0                   0     0        2       BHK
# 29450    Dealer        37.8                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE             City_Name  LONGITUDE  \
# ...

# %%
dataset.to_csv("House Price.csv",index=False)

# %%
Bang_Price_5lac=dataset.loc[dataset["City_Name"]=="Bangalore"]

# %%
Bang_Price_5lac
# Out:
#       POSTED_BY  Flat_Rates  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0         Owner        65.0                   0     0        2       BHK
# 2         Owner        53.0                   0     0        2       BHK
# 8        Dealer        51.6                   0     1        2       BHK
# 11       Dealer       120.0                   0     0        2       BHK
# 12        Owner        58.0                   0     0        2       BHK
# ...         ...         ...                 ...   ...      ...       ...
# 29408    Dealer        52.0                   0     0        2       BHK
# 29415     Owner       230.0                   0     0        4       BHK
# 29421    Dealer       107.0                   0     0        2       BHK
# 29433     Owner        60.0                   0     0        2       BHK
# 29436     Owner        72.0                   1     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE  City_Name  LONGITUDE   LATITUDE  \
# ...

# %%
cols=[]
for x in Bang_Price_5lac["TARGET(PRICE_IN_LACS)"]:
    x2=x-5
    cols.append(x2)

# %%
cols
# Out:
# [50.0,
#  38.0,
#  36.6,
#  105.0,
#  43.0,
#  175.0,
#  115.0,
#  70.0,
#  63.5,
#  69.0,
#  135.0,
#  43.0,
#  145.0,
#  19.5,
#  75.0,
#  65.0,
#  43.0,
#  57.0,
#  95.0,
#  33.0,
#  145.0,
#  83.0,
#  95.0,
#  70.0,
#  245.0,
#  50.0,
#  45.7,
#  90.0,
#  85.0,
#  74.5,
#  93.0,
#  71.5,
#  21.0,
#  65.0,
#  56.0,
#  245.0,
#  47.0,
#  465.0,
#  41.0,
#  95.0,
#  90.0,
#  45.0,
#  22.0,
#  89.0,
#  80.0,
#  35.0,
#  335.0,
#  80.0,
#  51.0,
#  44.0,
#  33.0,
#  27.4,
#  165.0,
#  29.0,
#  26.0,
#  73.6,
#  40.0,
#  105.0,
#  21.0,
#  465.0,
#  89.0,
#  69.0,
#  105.0,
#  55.0,
#  41.8,
#  40.0,
#  22.0,
#  91.0,
#  235.0,
#  53.0,
#  345.0,
#  315.0,
#  40.0,
#  275.0,
#  475.0,
#  95.0,
#  65.0,
#  295.0,
#  20.3,
#  39.5,
#  395.0,
#  94.0,
#  105.0,
#  32.0,
#  87.0,
#  665.0,
#  82.0,
#  135.0,
#  40.7,
#  46.0,
#  90.0,
#  70.0,
#  92.6,
#  73.0,
#  71.0,
#  70.0,
#  41.0,
#  285.0,
#  105.0,
#  40.0,
#  55.0,
#  125.0,
#  64.9,
#  265.0,
#  375.0,
#  46.0,
#  28.5,
# ...

# %%
Bang_Price_5lac.insert(1,"Price_Updated",cols)

# %%
Bang_Price_5lac
# Out:
#       POSTED_BY  Price_Updated  Flat_Rates  UNDER_CONSTRUCTION  RERA  BHK_NO.  \
# 0         Owner           50.0        65.0                   0     0        2
# 2         Owner           38.0        53.0                   0     0        2
# 8        Dealer           36.6        51.6                   0     1        2
# 11       Dealer          105.0       120.0                   0     0        2
# 12        Owner           43.0        58.0                   0     0        2
# ...         ...            ...         ...                 ...   ...      ...
# 29408    Dealer           37.0        52.0                   0     0        2
# 29415     Owner          215.0       230.0                   0     0        4
# 29421    Dealer           92.0       107.0                   0     0        2
# 29433     Owner           45.0        60.0                   0     0        2
# 29436     Owner           57.0        72.0                   1     1        2
#
# ...

# %%
Bang_Price_5lac.round(2)
# Out:
#       POSTED_BY  Price_Updated  Flat_Rates  UNDER_CONSTRUCTION  RERA  BHK_NO.  \
# 0         Owner           50.0        65.0                   0     0        2
# 2         Owner           38.0        53.0                   0     0        2
# 8        Dealer           36.6        51.6                   0     1        2
# 11       Dealer          105.0       120.0                   0     0        2
# 12        Owner           43.0        58.0                   0     0        2
# ...         ...            ...         ...                 ...   ...      ...
# 29408    Dealer           37.0        52.0                   0     0        2
# 29415     Owner          215.0       230.0                   0     0        4
# 29421    Dealer           92.0       107.0                   0     0        2
# 29433     Owner           45.0        60.0                   0     0        2
# 29436     Owner           57.0        72.0                   1     1        2
#
# ...

# %%
dataset
# Out:
#       POSTED_BY  Flat_Rates  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0         Owner        65.0                   0     0        2       BHK
# 1        Dealer        61.0                   0     0        2       BHK
# 2         Owner        53.0                   0     0        2       BHK
# 3         Owner        72.5                   0     1        2       BHK
# 4        Dealer        70.5                   1     0        2       BHK
# ...         ...         ...                 ...   ...      ...       ...
# 29446     Owner        55.0                   0     0        3       BHK
# 29447     Owner        26.0                   0     0        2       BHK
# 29448    Dealer        37.1                   0     0        2       BHK
# 29449     Owner        77.0                   0     0        2       BHK
# 29450    Dealer        37.8                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE             City_Name  LONGITUDE  \
# ...

# %%
data=dataset["POSTED_BY"].replace("Owner","Ow")

# %%
data
# Out:
# 0            Ow
# 1        Dealer
# 2            Ow
# 3            Ow
# 4        Dealer
#           ...
# 29446        Ow
# 29447        Ow
# 29448    Dealer
# 29449        Ow
# 29450    Dealer
# Name: POSTED_BY, Length: 29451, dtype: object

# %%
dataset["POSTED_BY"].replace("Owner","_Flates")
# Out:
# 0        _Flates
# 1         Dealer
# 2        _Flates
# 3        _Flates
# 4         Dealer
#           ...
# 29446    _Flates
# 29447    _Flates
# 29448     Dealer
# 29449    _Flates
# 29450     Dealer
# Name: POSTED_BY, Length: 29451, dtype: object

# %%
dataset["POSTED_BY"]=dataset["POSTED_BY"].replace("Owner","Own_Flates")

# %%
dataset
# Out:
#       POSTED_BY  Flat_Rates  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0       _Flates        65.0                   0     0        2       BHK
# 1        Dealer        61.0                   0     0        2       BHK
# 2       _Flates        53.0                   0     0        2       BHK
# 3       _Flates        72.5                   0     1        2       BHK
# 4        Dealer        70.5                   1     0        2       BHK
# ...         ...         ...                 ...   ...      ...       ...
# 29446   _Flates        55.0                   0     0        3       BHK
# 29447   _Flates        26.0                   0     0        2       BHK
# 29448    Dealer        37.1                   0     0        2       BHK
# 29449   _Flates        77.0                   0     0        2       BHK
# 29450    Dealer        37.8                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE             City_Name  LONGITUDE  \
# ...

# %%
dataset=pd.read_csv(r"D:\My Work\Top_Dataset\HousePrice.csv")

# %%
dataset["POSTED_BY"]=dataset["POSTED_BY"].str.replace("er","_Flates")

# %%
dataset["POSTED_BY"].unique()
# Out:
# array(['Own_Flates', 'Deal_Flates', 'Build_Flates'], dtype=object)

# %%
dataset["POSTED_BY"]=dataset["POSTED_BY"].str.replace("er","_Flates")

# %%
for x in dataset["POSTED_BY"]:
    print(x)
# Out:
# Own_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Deal_Flates
# Deal_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Deal_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Deal_Flates
# Deal_Flates
# Deal_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Deal_Flates
# Build_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Deal_Flates
# Deal_Flates
# Deal_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Deal_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Deal_Flates
# Own_Flates
# Own_Flates
# Own_Flates
# ...

# %%
dataset=pd.read_csv(r"D:\My Work\Top_Dataset\HousePrice.csv")

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
ab=[]
for x in dataset["POSTED_BY"]:
    if x =="Owner":
        ab1=x.replace("er","_Flates")
        ab.append(ab1)
    else:
        ab.append(x)

# %%
dataset.insert(3,"Replaced Data",ab)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA Replaced Data  BHK_NO. BHK_OR_RK  \
# 0         Owner                   0     0    Own_Flates        2       BHK
# 1        Dealer                   0     0        Dealer        2       BHK
# 2         Owner                   0     0    Own_Flates        2       BHK
# 3         Owner                   0     1    Own_Flates        2       BHK
# 4        Dealer                   1     0        Dealer        2       BHK
# ...         ...                 ...   ...           ...      ...       ...
# 29446     Owner                   0     0    Own_Flates        3       BHK
# 29447     Owner                   0     0    Own_Flates        2       BHK
# 29448    Dealer                   0     0        Dealer        2       BHK
# 29449     Owner                   0     0    Own_Flates        2       BHK
# 29450    Dealer                   0     1        Dealer        2       BHK
#
# ...

# %%
dataset["Replaced Data"].unique()
# Out:
# array(['Own_Flates', 'Dealer', 'Builder'], dtype=object)
